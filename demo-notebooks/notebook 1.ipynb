# %% [markdown]
# # Learn magic commands

# %%
# %sql
CREATE SCHEMA test;
USE schema test;
CREATE TABLE student(in INT, name STRING, class STRING, section STRING, shift STRING);
INSERT INTO student VALUES (1,'Aritri','N2','A','M'),(2,'Arohi','N1','C','M'),(3,'Aryan','N1','B','M');
